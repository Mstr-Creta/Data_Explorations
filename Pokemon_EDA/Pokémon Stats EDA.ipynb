# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
#  <a id = "1"></a><br>
#
# ## Basic Analysis

# %%
#importing all important packages
import numpy as np #linear algebra
import pandas as pd #data processing
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns #data visualisation
# %matplotlib inline

# %%
#Input Data
data = pd.read_csv("Pokemon.csv") #reading csv file and save it into a variable
data.head(10) #show the first 10 rows in data
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# Data contents: 12 Columns
# * *Name*       : Nominal data
# * *Type 1*     : Nominal data
# * *Type 2*     : Nominal data
# * *Total *     : Ratio data
# * *HP *        : Ratio data
# * *Attack*     : Ratio data
# * *Defense*    : Ratio data
# * *Sp Atk*     : Ratio data
# * *Sp Def*     : Ratio data
# * *Speed*      : Ratio data
# * *Generation* : Ordinal data
# * *Legendary*  : Nominal data

# %% [markdown]
# <a id = "2"></a>
# ### Data Cleaning
# Need to remove all characters before "Mega".

# %%
data.Name = data.Name.str.replace(".*(?=Mega)", "")
data.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
data = data.set_index('Name') #change and set the index to the name attribute
data = data.drop(['#'],axis=1) #drop the columns with axis=1; axis=0 is for rows
data.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %% [markdown]
# If we look at row 5, there is a NaN type in the *Type 2* row. We can choose to delete or fill in the data. But in this case if we delete rows that has NaN, then it will mess up our data. Then we'll choose to fill it by copying the data from *Type 1* column.

# %%
data['Type 2'].fillna(data['Type 1'], inplace=True)
data.head(10)
# Out:
# C:\Users\maste\AppData\Local\Temp\ipykernel_6348\1901330840.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Type 2'].fillna(data['Type 1'], inplace=True)
#                           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                  Grass  Poison    318  45      49       49       65
# Ivysaur                    Grass  Poison    405  60      62       63       80
# Venusaur                   Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur      Grass  Poison    625  80     100      123      122
# Charmander                  Fire    Fire    309  39      52       43       60
# Charmeleon                  Fire    Fire    405  58      64       58       80
# Charizard                   Fire  Flying    534  78      84       78      109
# CharizardMega Charizard X   Fire  Dragon    634  78     130      111      130
# CharizardMega Charizard Y   Fire  Flying    634  78     104       78      159
# Squirtle                   Water   Water    314  44      48       65       50
#
#                            Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                       65     45           1      False
# Ivysaur                         80     60           1      False
# Venusaur                       100     80           1      False
# VenusaurMega Venusaur          120     80           1      False
# Charmander                      50     65           1      False
# Charmeleon                      65     80           1      False
# Charizard                       85    100           1      False
# CharizardMega Charizard X       85    100           1      False
# CharizardMega Charizard Y      115    100           1      False
# Squirtle                        64     43           1      False

# %% [markdown]
# <a id = "3"></a>
# ### Frequency

# %%
print("Type 1:",data["Type 1"].unique(), "=", len(data["Type 1"].unique()))
print("Type 2:",data["Type 2"].unique(), "=", len(data["Type 2"].unique()))
# Out:
# Type 1: ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying'] = 18
# Type 2: ['Poison' 'Fire' 'Flying' 'Dragon' 'Water' 'Bug' 'Normal' 'Electric'
#  'Ground' 'Fairy' 'Grass' 'Fighting' 'Psychic' 'Steel' 'Ice' 'Rock' 'Dark'
#  'Ghost'] = 18

# %% [markdown]
# There are 18 unique types.

# %%
print(data["Type 1"].value_counts())
print(data["Type 2"].value_counts())
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64
# Type 2
# Flying      99
# Water       73
# Psychic     71
# Normal      65
# Grass       58
# Poison      49
# Ground      48
# Fighting    46
# Fire        40
# Fairy       38
# Electric    33
# Dark        30
# Dragon      29
# Steel       27
# Ice         27
# Ghost       24
# Rock        23
# Bug         20
# Name: count, dtype: int64

# %% [markdown]
# Highest frequency in *Type 1* is **Water**
# *Type 2* is **Flying**,
# While, the lowest frequency in *Type 1* is **Flying**
# and in *Type 2* is **Bug**

# %% [markdown]
# <a id = "4"></a>
# ### The Strongest and The Weakest
# **Who is the strongest and the weakest Pokemons by types?** We will find out.

# %%
strongest = data.sort_values(by='Total', ascending=False) #sorting the rows in descending order
strongest.drop_duplicates(subset=['Type 1'],keep='first')
#since the rows are now sorted in descending order
#thus we take the first row for every new type of pokemon
# Out:
#                            Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# RayquazaMega Rayquaza      Dragon    Flying    780  105     180      100
# MewtwoMega Mewtwo X       Psychic  Fighting    780  106     190      100
# KyogrePrimal Kyogre         Water     Water    770  100     150       90
# GroudonPrimal Groudon      Ground      Fire    770  100     180      160
# Arceus                     Normal    Normal    720  120     120      120
# MetagrossMega Metagross     Steel   Psychic    700   80     145      150
# DiancieMega Diancie          Rock     Fairy    700   50     160      110
# GiratinaAltered Forme       Ghost    Dragon    680  150     100      120
# Ho-oh                        Fire    Flying    680  106     130       90
# Xerneas                     Fairy     Fairy    680  126     131       95
# Yveltal                      Dark    Flying    680  126     131       95
# SceptileMega Sceptile       Grass    Dragon    630   70     110       75
# LucarioMega Lucario      Fighting     Steel    625   70     145       88
# AmpharosMega Ampharos    Electric    Dragon    610   90      95      105
# PinsirMega Pinsir             Bug    Flying    600   65     155      120
# GlalieMega Glalie             Ice       Ice    580   80     120       80
# TornadusTherian Forme      Flying    Flying    580   79     100       80
# Crobat                     Poison    Flying    535   85      90       80
#
#                          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# RayquazaMega Rayquaza        180      100    115           3       True
# MewtwoMega Mewtwo X          154      100    130           1       True
# KyogrePrimal Kyogre          180      160     90           3       True
# GroudonPrimal Groudon        150       90     90           3       True
# Arceus                       120      120    120           4       True
# MetagrossMega Metagross      105      110    110           3      False
# DiancieMega Diancie          160      110    110           6       True
# GiratinaAltered Forme        100      120     90           4       True
# Ho-oh                        110      154     90           2       True
# Xerneas                      131       98     99           6       True
# Yveltal                      131       98     99           6       True
# SceptileMega Sceptile        145       85    145           3      False
# LucarioMega Lucario          140       70    112           4      False
# AmpharosMega Ampharos        165      110     45           2      False
# PinsirMega Pinsir             65       90    105           1      False
# GlalieMega Glalie            120       80    100           3      False
# TornadusTherian Forme        110       90    121           5       True
# Crobat                        70       80    130           2      False

# %% [markdown]
# So, we finally know who is the strongest pokemons by types. And also the strongest of the strongest pokemon is **Mega Rayquaza**, the Dragon type. And also we know that 10/18 Strongest Pokemons by types are Legendary. Let's check who is the weakest by types.

# %%
weakest = data.sort_values(by='Total') #sorting the rows in ascending order
weakest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#               Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Sunkern        Grass     Grass    180  30      30       30       30       30
# Azurill       Normal     Fairy    190  50      20       40       20       40
# Kricketot        Bug       Bug    194  37      25       41       25       41
# Ralts        Psychic     Fairy    198  28      25       25       45       35
# Feebas         Water     Water    200  20      15       20       10       55
# Pichu       Electric  Electric    205  20      40       15       35       35
# Tyrogue     Fighting  Fighting    210  35      35       35       35       35
# Cleffa         Fairy     Fairy    218  50      25       28       45       55
# Poochyena       Dark      Dark    220  35      55       35       30       30
# Noibat        Flying    Dragon    245  40      30       35       45       40
# Zubat         Poison    Flying    245  40      45       35       30       40
# Slugma          Fire      Fire    250  40      40       40       70       40
# Swinub           Ice    Ground    250  50      50       40       30       30
# Diglett       Ground    Ground    265  10      55       25       35       45
# Litwick        Ghost      Fire    275  50      30       55       65       55
# Roggenrola      Rock      Rock    280  55      75       85       25       25
# Gible         Dragon    Ground    300  58      70       45       40       45
# Klink          Steel     Steel    300  40      55       70       45       60
#
#             Speed  Generation  Legendary
# Name
# Sunkern        30           2      False
# Azurill        20           3      False
# Kricketot      25           4      False
# Ralts          40           3      False
# Feebas         80           3      False
# Pichu          60           2      False
# Tyrogue        35           2      False
# Cleffa         15           2      False
# Poochyena      35           3      False
# Noibat         55           6      False
# Zubat          55           1      False
# Slugma         20           2      False
# Swinub         50           2      False
# Diglett        95           1      False
# Litwick        20           5      False
# Roggenrola     15           5      False
# Gible          42           4      False
# Klink          30           5      False

# %% [markdown]
# The weakest of the weakest pokemon is **Sunkern**.

# %% [markdown]
# <a id = "5"></a>
# ### The Fastest and The Slowest

# %%
fastest = data.sort_values(by='Speed', ascending=False) #sorting the rows in descending order
fastest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                              Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# DeoxysSpeed Forme           Psychic   Psychic    600   50      95       90
# Ninjask                         Bug    Flying    456   61      90       45
# AerodactylMega Aerodactyl      Rock    Flying    615   80     135       85
# SceptileMega Sceptile         Grass    Dragon    630   70     110       75
# Electrode                  Electric  Electric    480   60      50       70
# LopunnyMega Lopunny          Normal  Fighting    580   65     136       94
# Crobat                       Poison    Flying    535   85      90       80
# GengarMega Gengar             Ghost    Poison    600   60      65       80
# Talonflame                     Fire    Flying    499   78      81       71
# Weavile                        Dark       Ice    510   70     120       65
# Noivern                      Flying    Dragon    535   85      70       80
# Greninja                      Water      Dark    530   72      95       67
# SalamenceMega Salamence      Dragon    Flying    700   95     145      130
# Dugtrio                      Ground    Ground    405   35      80       50
# Hawlucha                   Fighting    Flying    500   78      92       75
# Froslass                        Ice     Ghost    480   70      80       70
# MetagrossMega Metagross       Steel   Psychic    700   80     145      150
# Xerneas                       Fairy     Fairy    680  126     131       95
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# DeoxysSpeed Forme               95       90    180           3       True
# Ninjask                         50       50    160           3      False
# AerodactylMega Aerodactyl       70       95    150           1      False
# SceptileMega Sceptile          145       85    145           3      False
# Electrode                       80       80    140           1      False
# LopunnyMega Lopunny             54       96    135           4      False
# Crobat                          70       80    130           2      False
# GengarMega Gengar              170       95    130           1      False
# Talonflame                      74       69    126           6      False
# Weavile                         45       85    125           4      False
# Noivern                         97       80    123           6      False
# Greninja                       103       71    122           6      False
# SalamenceMega Salamence        120       90    120           3      False
# Dugtrio                         50       70    120           1      False
# Hawlucha                        74       63    118           6      False
# Froslass                        80       70    110           4      False
# MetagrossMega Metagross        105      110    110           3      False
# Xerneas                        131       98     99           6       True

# %% [markdown]
# The Fastest pokemon is **DeoxysSpeed Forme** which is a Legendary Psychic pokemon.

# %%
slowest = data.sort_values(by='Speed') #sorting the rows in ascending order
slowest.drop_duplicates(subset=['Type 1'],keep='first')
# Out:
#                        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Munchlax               Normal    Normal    390  135      85       40       40
# Shuckle                   Bug      Rock    505   20      10      230       10
# Trapinch               Ground    Ground    290   45     100       45       45
# Bonsly                   Rock      Rock    290   50      80       95       10
# Ferroseed               Grass     Steel    305   44      50       91       24
# Slowpoke                Water   Psychic    315   90      65       65       40
# Cleffa                  Fairy     Fairy    218   50      25       28       45
# Torkoal                  Fire      Fire    470   70      85      140       85
# Litwick                 Ghost      Fire    275   50      30       55       65
# Solosis               Psychic   Psychic    290   45      30       40      105
# SableyeMega Sableye      Dark     Ghost    480   50      85      125       85
# Bronzor                 Steel   Psychic    300   57      24       86       24
# Spheal                    Ice     Water    290   70      40       50       55
# Grimer                 Poison    Poison    325   80      80       50       40
# Makuhita             Fighting  Fighting    237   72      60       30       20
# Mareep               Electric  Electric    280   55      40       40       65
# Goomy                  Dragon    Dragon    300   45      50       35       55
# Noibat                 Flying    Dragon    245   40      30       35       45
#
#                      Sp. Def  Speed  Generation  Legendary
# Name
# Munchlax                  85      5           4      False
# Shuckle                  230      5           2      False
# Trapinch                  45     10           3      False
# Bonsly                    45     10           4      False
# Ferroseed                 86     10           5      False
# Slowpoke                  40     15           1      False
# Cleffa                    55     15           2      False
# Torkoal                   70     20           3      False
# Litwick                   55     20           5      False
# Solosis                   50     20           5      False
# SableyeMega Sableye      115     20           3      False
# Bronzor                   86     23           4      False
# Spheal                    50     25           3      False
# Grimer                    50     25           1      False
# Makuhita                  30     25           3      False
# Mareep                    45     35           2      False
# Goomy                     75     40           6      False
# Noibat                    40     55           6      False

# %% [markdown]
# <a id = "6"></a>
# ### Summary

# %%
#now, let's summary the data
data.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# _________________________________________________________

# %% [markdown]
# <a id = "7"></a>
# ## Data Visualisation

# %% [markdown]
# <a id = "8"></a>
# ### Count Plot

# %%
sns.set(style = 'whitegrid', palette = 'muted') 
sns.set_context("notebook", font_scale=1.5)

f, ax = plt.subplots(2,1, figsize = (18,10)) 

sns.countplot(x = 'Type 1', data = data, order = data['Type 1'].value_counts().index ,ax = ax[0])
sns.countplot(x = 'Type 2', data = data, order = data['Type 2'].value_counts().index ,ax = ax[1])

plt.show()

# %% [markdown]
# <a id = "9"></a>
# ### Percentages for each type

# %%
#we create a dictionary to make process easier
types_count = {'Grass' : 0, 'Fire' : 0, 'Water' : 0, 'Bug' : 0, 'Normal' : 0, 'Poison' : 0, 
               'Electric' : 0, 'Ground' : 0, 'Fairy' : 0, 'Fighting' : 0, 'Psychic' : 0, 
               'Rock' : 0, 'Ghost' : 0, 'Ice' : 0, 'Dragon' : 0, 'Dark' : 0, 'Steel' : 0, 'Flying' : 0}

type1 = data["Type 1"]
type2 = data["Type 2"]

for i in range(len(type1)):
    
    #first, count the Type 1 column
    types_count[type1[i]] += 1
    
    #now we count the Type 2 column and avoid double counting
    if type1[i] != type2[i]:
        types_count[type2[i]] += 1

for t in types_count:
    print("{:10} = {}".format(t,types_count[t]))
# Out:
# Grass      = 95
# Fire       = 64
# Water      = 126
# Bug        = 72
# Normal     = 102
# Poison     = 62
# Electric   = 50
# Ground     = 67
# Fairy      = 40
# Fighting   = 53
# Psychic    = 90
# Rock       = 58
# Ghost      = 46
# Ice        = 38
# Dragon     = 50
# Dark       = 51
# Steel      = 49
# Flying     = 101
# C:\Users\maste\AppData\Local\Temp\ipykernel_6348\1046356797.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types_count[type1[i]] += 1
# C:\Users\maste\AppData\Local\Temp\ipykernel_6348\1046356797.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if type1[i] != type2[i]:
# C:\Users\maste\AppData\Local\Temp\ipykernel_6348\1046356797.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types_count[type2[i]] += 1

# %% [markdown]
# We got overall count from both types, now it's time to get *Type 1* count and *Type 2* count.

# %%
type1_count = {'Grass' : 0, 'Fire' : 0, 'Water' : 0, 'Bug' : 0, 'Normal' : 0, 'Poison' : 0, 
               'Electric' : 0, 'Ground' : 0, 'Fairy' : 0, 'Fighting' : 0, 'Psychic' : 0, 
               'Rock' : 0, 'Ghost' : 0, 'Ice' : 0, 'Dragon' : 0, 'Dark' : 0, 'Steel' : 0,
               'Flying' : 0}
type2_count = {'Grass' : 0, 'Fire' : 0, 'Water' : 0, 'Bug' : 0, 'Normal' : 0, 'Poison' : 0, 
               'Electric' : 0, 'Ground' : 0, 'Fairy' : 0, 'Fighting' : 0, 'Psychic' : 0, 
               'Rock' : 0, 'Ghost' : 0, 'Ice' : 0, 'Dragon' : 0, 'Dark' : 0, 'Steel' : 0,
               'Flying' : 0}

for i in range(len(type1)):
    type1_count[type1[i]] += 1
    type2_count[type2[i]] += 1

print("TYPE 1")
for t in type1_count:
    print("{:10} = {}".format(t,type1_count[t]))
print("-------------------")
print("TYPE 2")
for t in type2_count:
    print("{:10} = {}".format(t,type2_count[t]))
# Out:
# TYPE 1
# Grass      = 70
# Fire       = 52
# Water      = 112
# Bug        = 69
# Normal     = 98
# Poison     = 28
# Electric   = 44
# Ground     = 32
# Fairy      = 17
# Fighting   = 27
# Psychic    = 57
# Rock       = 44
# Ghost      = 32
# Ice        = 24
# Dragon     = 32
# Dark       = 31
# Steel      = 27
# Flying     = 4
# -------------------
# TYPE 2
# Grass      = 58
# Fire       = 40
# Water      = 73
# Bug        = 20
# Normal     = 65
# Poison     = 49
# Electric   = 33
# Ground     = 48
# Fairy      = 38
# Fighting   = 46
# Psychic    = 71
# Rock       = 23
# Ghost      = 24
# Ice        = 27
# Dragon     = 29
# Dark       = 30
# Steel      = 27
# Flying     = 99
# C:\Users\maste\AppData\Local\Temp\ipykernel_6348\3254927572.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type1_count[type1[i]] += 1
# C:\Users\maste\AppData\Local\Temp\ipykernel_6348\3254927572.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type2_count[type2[i]] += 1

# %% [markdown]
# Making 3 pie plots after iterations: Type 1 count, Type 2 count. and overall count,

# %%
f, axs = plt.subplots(2,2, figsize=(20,20))

labels ='Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric', 'Ground', \
        'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost' ,'Ice' ,'Dragon' ,'Dark' , \
        'Steel','Flying'
    
size0 = [95,64,126,72,102,62,50,67,40,53,90,58,46,38,50,51,49,101] #overall count
size1 = [70,52,112,69,98,28,44,32,17,27,57,44,32,24,32,31,27,4] #Type 1 count
size2 = [58,40,73,20,65,49,33,48,38,46,71,23,24,27,29,30,27,99] #Type 2 count

#Overall pie
axs[0,0].pie(size0, labels = labels, autopct='%1.1f%%' ,startangle = 90)
axs[0,0].axis("equal")
axs[0,0].set_title("Overall", size = 20)

#Type1 pie
axs[0,1].pie(size1, labels = labels, autopct='%1.1f%%' ,startangle = 180)
axs[0,1].axis("equal")
axs[0,1].set_title("Type 1", size = 20)

#Type2 pie
axs[1,0].pie(size2, labels = labels, autopct='%1.1f%%' ,startangle = 90)
axs[1,0].axis("equal")
axs[1,0].set_title("Type 2", size = 20)

f.delaxes(axs[1,1]) #deleting axs[1,1] so it will be white blank
plt.show()

# %% [markdown]
# <a id = "10"></a>
# ### All stats analysis of the pokemons

# %%
data2 = data.drop(['Generation', 'Total', 'Legendary'], axis = 1) #we drop some columns that unnecessary
data2.head()
# Out:
#                       Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur              Grass  Poison  45      49       49       65       65
# Ivysaur                Grass  Poison  60      62       63       80       80
# Venusaur               Grass  Poison  80      82       83      100      100
# VenusaurMega Venusaur  Grass  Poison  80     100      123      122      120
# Charmander              Fire    Fire  39      52       43       60       50
#
#                        Speed
# Name
# Bulbasaur                 45
# Ivysaur                   60
# Venusaur                  80
# VenusaurMega Venusaur     80
# Charmander                65

# %%
#stats for the Attack by Type 1
sns.set_style("whitegrid")

f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.boxplot(data = data2, x = 'Type 1', y = 'Attack')
ax.set_title(label='Attack by Type 1', size = 20)

plt.show()

# %% [markdown]
# We can conclude that the **Dragon** type pokemon has an advantage over other types because they have a higher attack compared to other types. Let's see the starter pokemon : Fire, Water, and Grass.
# Fire Pokemons have a higher attack than Water and Grass.

# %%
#stats for the Attack by Type 2
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.boxplot(data = data2, x = 'Type 2', y = 'Attack')
ax.set_title(label='Attack by Type 2', size = 20)

plt.show()

# %% [markdown]
# And from this chart, we can conclude that **Fighting** pokemon have a higher attack than other pokemon types. All pokemons that have Fighting as their second type have higher attack value.

# %%
#stats for the Defense by Type 1
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.violinplot(data = data2, x = 'Type 1', y = 'Defense')
ax.set_title(label='Defense by Type 1', size = 20)

plt.show()

# %% [markdown]
# This shows that **Steel ** pokemon have the highest defense compared the other types.

# %%
#stats for the Defense by Type 2
f, ax = plt.subplots(1,1, figsize = (20,10))

ax = sns.violinplot(data = data2, x = 'Type 2', y = 'Defense')
ax.set_title(label='Defense by Type 2', size = 20)

plt.show()
